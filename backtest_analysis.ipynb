# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"E:\ureca\AgentWorld\workdir\trading_strategy_agent\environment\backtest_history.csv")

# %%
df.head()
# Out:
#    Step  sharpe_ratio  cumulative_return (%)  max_drawdown (%)  win_rate (%)  \
# 0     5     -3.849750             -49.452824        -54.343858     54.729289
# 1     5     -6.051950             -76.491428        -76.493996     54.405594
# 2     5     -7.001584             -37.891680        -40.198370     53.873745
# 3     6     -0.296831              -0.779708         -2.534045     55.555556
# 4     6     -0.460999              -0.715244         -1.963568     60.000000
#
#    closed_trades  total_commission (%)  excess_return_ratio (%)  \
# 0         3066.0             79.658060               -69.289620
# 1         4290.0             75.775317               -71.636329
# 2         1394.0             39.998959               -49.433598
# 3            9.0              0.267555               -39.717842
# 4            5.0              0.147490                19.789505
#
#            strategy          signal       start         end      Type
# ...

# %%
sns.barplot(data=df, x="Step", y="cumulative_return (%)", hue="Type")
plt.title("Cumulative Return")
# Out:
# Text(0.5, 1.0, 'Cumulative Return')

# %%
sns.barplot(data=df, x="Step", y="excess_return_ratio (%)", hue="Type")
plt.title("Excess Return Ratio")
# Out:
# Text(0.5, 1.0, 'Excess Return Ratio')
